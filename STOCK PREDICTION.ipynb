# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\Saher\\Downloads\\INFY.csv')

# %%
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     1999-03-11   0.583984   0.781250   0.583984   0.732422   0.490145
# 1     1999-03-12   0.734375   0.761719   0.671875   0.728516   0.487531
# 2     1999-03-15   0.730469   0.730469   0.658203   0.662109   0.443090
# 3     1999-03-16   0.667969   0.691406   0.656250   0.656250   0.439170
# 4     1999-03-17   0.656250   0.699219   0.652344   0.660156   0.441783
# ...          ...        ...        ...        ...        ...        ...
# 6122  2023-07-11  16.260000  16.280001  16.150000  16.240000  16.240000
# 6123  2023-07-12  16.260000  16.290001  16.030001  16.070000  16.070000
# 6124  2023-07-13  16.580000  16.850000  16.580000  16.790001  16.790001
# 6125  2023-07-14  17.160000  17.200001  16.990000  17.040001  17.040001
# 6126  2023-07-17  17.049999  17.309999  17.030001  17.290001  17.290001
#
#          Volume
# 0     172512000
# 1      39897600
# 2      12672000
# 3       9984000
# 4      15449600
# ...         ...
# 6122    7631500
# 6123    7102600
# 6124   13295300
# 6125   11539700
# 6126   12633200
#
# [6127 rows x 7 columns]

# %%
df = df[['Date','Close']]
df
# Out:
#             Date      Close
# 0     1999-03-11   0.732422
# 1     1999-03-12   0.728516
# 2     1999-03-15   0.662109
# 3     1999-03-16   0.656250
# 4     1999-03-17   0.660156
# ...          ...        ...
# 6122  2023-07-11  16.240000
# 6123  2023-07-12  16.070000
# 6124  2023-07-13  16.790001
# 6125  2023-07-14  17.040001
# 6126  2023-07-17  17.290001
#
# [6127 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1999-03-11
# 1       1999-03-12
# 2       1999-03-15
# 3       1999-03-16
# 4       1999-03-17
#            ...
# 6122    2023-07-11
# 6123    2023-07-12
# 6124    2023-07-13
# 6125    2023-07-14
# 6126    2023-07-17
# Name: Date, Length: 6127, dtype: object

# %%
import datetime

def str_to_datetime(s):
    split = s.split('-')
    year, month, day = int(split[0]),int(split[1]),int(split[2])
    return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1999-03-11')
datetime_object
# Out:
# datetime.datetime(1999, 3, 11, 0, 0)

# %%
import warnings
warnings.filterwarnings('ignore')
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# 0      1999-03-11
# 1      1999-03-12
# 2      1999-03-15
# 3      1999-03-16
# 4      1999-03-17
#           ...
# 6122   2023-07-11
# 6123   2023-07-12
# 6124   2023-07-13
# 6125   2023-07-14
# 6126   2023-07-17
# Name: Date, Length: 6127, dtype: datetime64[ns]

# %%
#making date column the index

df.index = df.pop('Date')
df
# Out:
#                 Close
# Date
# 1999-03-11   0.732422
# 1999-03-12   0.728516
# 1999-03-15   0.662109
# 1999-03-16   0.656250
# 1999-03-17   0.660156
# ...               ...
# 2023-07-11  16.240000
# 2023-07-12  16.070000
# 2023-07-13  16.790001
# 2023-07-14  17.040001
# 2023-07-17  17.290001
#
# [6127 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2022-07-19'
windowed_df = df_to_windowed_df(df, 
                                '2022-07-19', 
                                '2023-07-17', 
                                n=3)
windowed_df
# Out:
#     Target Date   Target-3   Target-2   Target-1     Target
# 0    2022-07-19  17.900000  18.170000  18.440001  18.709999
# 1    2022-07-20  18.170000  18.440001  18.709999  18.719999
# 2    2022-07-21  18.440001  18.709999  18.719999  19.209999
# 3    2022-07-22  18.709999  18.719999  19.209999  18.879999
# 4    2022-07-25  18.719999  19.209999  18.879999  18.559999
# ..          ...        ...        ...        ...        ...
# 245  2023-07-11  16.070000  16.049999  16.010000  16.240000
# 246  2023-07-12  16.049999  16.010000  16.240000  16.070000
# 247  2023-07-13  16.010000  16.240000  16.070000  16.790001
# 248  2023-07-14  16.240000  16.070000  16.790001  17.040001
# 249  2023-07-17  16.070000  16.790001  17.040001  17.290001
#
# [250 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((250,), (250, 3, 1), (250,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 3s 105ms/step - loss: 303.5999 - mean_absolute_error: 17.3770 - val_loss: 201.1262 - val_mean_absolute_error: 14.1793
# Epoch 2/100
# 7/7 [==============================] - 0s 17ms/step - loss: 277.1786 - mean_absolute_error: 16.5989 - val_loss: 177.7252 - val_mean_absolute_error: 13.3286
# Epoch 3/100
# 7/7 [==============================] - 0s 11ms/step - loss: 247.4805 - mean_absolute_error: 15.6775 - val_loss: 148.5998 - val_mean_absolute_error: 12.1871
# Epoch 4/100
# 7/7 [==============================] - 0s 10ms/step - loss: 209.4213 - mean_absolute_error: 14.4066 - val_loss: 111.3269 - val_mean_absolute_error: 10.5475
# Epoch 5/100
# 7/7 [==============================] - 0s 10ms/step - loss: 159.5454 - mean_absolute_error: 12.5484 - val_loss: 65.8787 - val_mean_absolute_error: 8.1117
# Epoch 6/100
# 7/7 [==============================] - 0s 10ms/step - loss: 99.3927 - mean_absolute_error: 9.8489 - val_loss: 23.2736 - val_mean_absolute_error: 4.8159
# Epoch 7/100
# 7/7 [==============================] - 0s 10ms/step - loss: 41.7329 - mean_absolute_error: 6.2271 - val_loss: 0.4916 - val_mean_absolute_error: 0.6418
# Epoch 8/100
# 7/7 [==============================] - 0s 10ms/step - loss: 7.0855 - mean_absolute_error: 2.2665 - val_loss: 12.0844 - val_mean_absolute_error: 3.4650
# Epoch 9/100
# 7/7 [==============================] - 0s 11ms/step - loss: 4.2576 - mean_absolute_error: 1.6207 - val_loss: 24.8802 - val_mean_absolute_error: 4.9803
# Epoch 10/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5.2167 - mean_absolute_error: 1.8706 - val_loss: 14.6996 - val_mean_absolute_error: 3.8240
# Epoch 11/100
# 7/7 [==============================] - 0s 9ms/step - loss: 2.0057 - mean_absolute_error: 1.0623 - val_loss: 6.2591 - val_mean_absolute_error: 2.4865
# Epoch 12/100
# 7/7 [==============================] - 0s 11ms/step - loss: 2.0591 - mean_absolute_error: 1.1816 - val_loss: 4.5595 - val_mean_absolute_error: 2.1174
# Epoch 13/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.0873 - mean_absolute_error: 1.2006 - val_loss: 6.1450 - val_mean_absolute_error: 2.4636
# Epoch 14/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7436 - mean_absolute_error: 1.0390 - val_loss: 8.8941 - val_mean_absolute_error: 2.9696
# Epoch 15/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7979 - mean_absolute_error: 1.0150 - val_loss: 9.8826 - val_mean_absolute_error: 3.1317
# Epoch 16/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7903 - mean_absolute_error: 1.0159 - val_loss: 8.4885 - val_mean_absolute_error: 2.9006
# Epoch 17/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7152 - mean_absolute_error: 1.0141 - val_loss: 7.0496 - val_mean_absolute_error: 2.6410
# Epoch 18/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1.7713 - mean_absolute_error: 1.0569 - val_loss: 6.5786 - val_mean_absolute_error: 2.5503
# Epoch 19/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7372 - mean_absolute_error: 1.0374 - val_loss: 7.7756 - val_mean_absolute_error: 2.7751
# Epoch 20/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.6952 - mean_absolute_error: 1.0046 - val_loss: 8.1660 - val_mean_absolute_error: 2.8446
# Epoch 21/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.6940 - mean_absolute_error: 1.0062 - val_loss: 7.5693 - val_mean_absolute_error: 2.7378
# Epoch 22/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.6765 - mean_absolute_error: 1.0039 - val_loss: 7.6949 - val_mean_absolute_error: 2.7607
# Epoch 23/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1.6696 - mean_absolute_error: 1.0004 - val_loss: 7.8015 - val_mean_absolute_error: 2.7800
# Epoch 24/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.6680 - mean_absolute_error: 0.9931 - val_loss: 8.3064 - val_mean_absolute_error: 2.8694
# Epoch 25/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.6669 - mean_absolute_error: 0.9920 - val_loss: 7.8614 - val_mean_absolute_error: 2.7908
# Epoch 26/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.6529 - mean_absolute_error: 0.9957 - val_loss: 7.1183 - val_mean_absolute_error: 2.6544
# Epoch 27/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.6552 - mean_absolute_error: 1.0066 - val_loss: 6.9510 - val_mean_absolute_error: 2.6228
# Epoch 28/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.6379 - mean_absolute_error: 1.0004 - val_loss: 7.1641 - val_mean_absolute_error: 2.6632
# Epoch 29/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.6230 - mean_absolute_error: 0.9912 - val_loss: 7.1369 - val_mean_absolute_error: 2.6583
# Epoch 30/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5850 - mean_absolute_error: 0.9788 - val_loss: 6.7871 - val_mean_absolute_error: 2.5921
# Epoch 31/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.5252 - mean_absolute_error: 0.9634 - val_loss: 6.3386 - val_mean_absolute_error: 2.5043
# Epoch 32/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4842 - mean_absolute_error: 0.9536 - val_loss: 6.0912 - val_mean_absolute_error: 2.4548
# Epoch 33/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4557 - mean_absolute_error: 0.9367 - val_loss: 6.5207 - val_mean_absolute_error: 2.5412
# Epoch 34/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.3942 - mean_absolute_error: 0.9127 - val_loss: 6.0749 - val_mean_absolute_error: 2.4521
# Epoch 35/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1.3662 - mean_absolute_error: 0.9047 - val_loss: 6.1906 - val_mean_absolute_error: 2.4757
# Epoch 36/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.3459 - mean_absolute_error: 0.9019 - val_loss: 5.7864 - val_mean_absolute_error: 2.3927
# Epoch 37/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.3204 - mean_absolute_error: 0.8924 - val_loss: 5.7993 - val_mean_absolute_error: 2.3955
# Epoch 38/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.2996 - mean_absolute_error: 0.8858 - val_loss: 5.5785 - val_mean_absolute_error: 2.3492
# Epoch 39/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.2794 - mean_absolute_error: 0.8796 - val_loss: 5.4951 - val_mean_absolute_error: 2.3316
# Epoch 40/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.2474 - mean_absolute_error: 0.8668 - val_loss: 5.2019 - val_mean_absolute_error: 2.2681
# Epoch 41/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.2350 - mean_absolute_error: 0.8717 - val_loss: 5.1428 - val_mean_absolute_error: 2.2552
# Epoch 42/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1.1983 - mean_absolute_error: 0.8464 - val_loss: 5.6723 - val_mean_absolute_error: 2.3700
# Epoch 43/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1.1833 - mean_absolute_error: 0.8380 - val_loss: 4.7749 - val_mean_absolute_error: 2.1723
# Epoch 44/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.1654 - mean_absolute_error: 0.8488 - val_loss: 5.0479 - val_mean_absolute_error: 2.2346
# Epoch 45/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1.1456 - mean_absolute_error: 0.8230 - val_loss: 5.3027 - val_mean_absolute_error: 2.2911
# Epoch 46/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.1076 - mean_absolute_error: 0.8140 - val_loss: 4.4678 - val_mean_absolute_error: 2.1010
# Epoch 47/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.0711 - mean_absolute_error: 0.8040 - val_loss: 4.6244 - val_mean_absolute_error: 2.1388
# Epoch 48/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.9877 - mean_absolute_error: 0.7742 - val_loss: 3.5881 - val_mean_absolute_error: 1.8819
# Epoch 49/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.9130 - mean_absolute_error: 0.7517 - val_loss: 3.3510 - val_mean_absolute_error: 1.8188
# Epoch 50/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.8140 - mean_absolute_error: 0.7154 - val_loss: 3.0061 - val_mean_absolute_error: 1.7220
# Epoch 51/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.7533 - mean_absolute_error: 0.6780 - val_loss: 2.6191 - val_mean_absolute_error: 1.6061
# Epoch 52/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.7074 - mean_absolute_error: 0.6711 - val_loss: 2.9181 - val_mean_absolute_error: 1.6970
# Epoch 53/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6615 - mean_absolute_error: 0.6410 - val_loss: 2.0460 - val_mean_absolute_error: 1.4173
# Epoch 54/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6199 - mean_absolute_error: 0.6188 - val_loss: 1.5142 - val_mean_absolute_error: 1.2153
# Epoch 55/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6054 - mean_absolute_error: 0.6181 - val_loss: 2.1245 - val_mean_absolute_error: 1.4453
# Epoch 56/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5119 - mean_absolute_error: 0.5676 - val_loss: 1.5828 - val_mean_absolute_error: 1.2439
# Epoch 57/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.5022 - mean_absolute_error: 0.5528 - val_loss: 1.8091 - val_mean_absolute_error: 1.3323
# Epoch 58/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4400 - mean_absolute_error: 0.5220 - val_loss: 1.0914 - val_mean_absolute_error: 1.0280
# Epoch 59/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4442 - mean_absolute_error: 0.5227 - val_loss: 1.7129 - val_mean_absolute_error: 1.2963
# Epoch 60/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4201 - mean_absolute_error: 0.5219 - val_loss: 1.1510 - val_mean_absolute_error: 1.0577
# Epoch 61/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3743 - mean_absolute_error: 0.4812 - val_loss: 1.1200 - val_mean_absolute_error: 1.0432
# Epoch 62/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3419 - mean_absolute_error: 0.4614 - val_loss: 1.0564 - val_mean_absolute_error: 1.0126
# Epoch 63/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3207 - mean_absolute_error: 0.4508 - val_loss: 1.1997 - val_mean_absolute_error: 1.0816
# Epoch 64/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3032 - mean_absolute_error: 0.4306 - val_loss: 0.6759 - val_mean_absolute_error: 0.8037
# Epoch 65/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2759 - mean_absolute_error: 0.4083 - val_loss: 0.5643 - val_mean_absolute_error: 0.7317
# Epoch 66/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2312 - mean_absolute_error: 0.3829 - val_loss: 0.3657 - val_mean_absolute_error: 0.5813
# Epoch 67/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1836 - mean_absolute_error: 0.3392 - val_loss: 0.3206 - val_mean_absolute_error: 0.5417
# Epoch 68/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1666 - mean_absolute_error: 0.3148 - val_loss: 0.2312 - val_mean_absolute_error: 0.4516
# Epoch 69/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1504 - mean_absolute_error: 0.2976 - val_loss: 0.0728 - val_mean_absolute_error: 0.2344
# Epoch 70/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1222 - mean_absolute_error: 0.2665 - val_loss: 0.0393 - val_mean_absolute_error: 0.1571
# Epoch 71/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1356 - mean_absolute_error: 0.2879 - val_loss: 0.0277 - val_mean_absolute_error: 0.1252
# Epoch 72/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1158 - mean_absolute_error: 0.2584 - val_loss: 0.0674 - val_mean_absolute_error: 0.2250
# Epoch 73/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1143 - mean_absolute_error: 0.2550 - val_loss: 0.0285 - val_mean_absolute_error: 0.1279
# Epoch 74/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1199 - mean_absolute_error: 0.2567 - val_loss: 0.0378 - val_mean_absolute_error: 0.1527
# Epoch 75/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1414 - mean_absolute_error: 0.2954 - val_loss: 0.0470 - val_mean_absolute_error: 0.1763
# Epoch 76/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1263 - mean_absolute_error: 0.2682 - val_loss: 0.0526 - val_mean_absolute_error: 0.1891
# Epoch 77/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1177 - mean_absolute_error: 0.2591 - val_loss: 0.0381 - val_mean_absolute_error: 0.1537
# Epoch 78/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1141 - mean_absolute_error: 0.2437 - val_loss: 0.1085 - val_mean_absolute_error: 0.2923
# Epoch 79/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1450 - mean_absolute_error: 0.2864 - val_loss: 0.0288 - val_mean_absolute_error: 0.1249
# Epoch 80/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1097 - mean_absolute_error: 0.2437 - val_loss: 0.0305 - val_mean_absolute_error: 0.1343
# Epoch 81/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1298 - mean_absolute_error: 0.2702 - val_loss: 0.0292 - val_mean_absolute_error: 0.1264
# Epoch 82/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1164 - mean_absolute_error: 0.2507 - val_loss: 0.1007 - val_mean_absolute_error: 0.2799
# Epoch 83/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1451 - mean_absolute_error: 0.3021 - val_loss: 0.1370 - val_mean_absolute_error: 0.3350
# Epoch 84/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1962 - mean_absolute_error: 0.3507 - val_loss: 0.0346 - val_mean_absolute_error: 0.1452
# Epoch 85/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1209 - mean_absolute_error: 0.2590 - val_loss: 0.0523 - val_mean_absolute_error: 0.1926
# Epoch 86/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1116 - mean_absolute_error: 0.2419 - val_loss: 0.0402 - val_mean_absolute_error: 0.1606
# Epoch 87/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1126 - mean_absolute_error: 0.2508 - val_loss: 0.0289 - val_mean_absolute_error: 0.1306
# Epoch 88/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1046 - mean_absolute_error: 0.2358 - val_loss: 0.0424 - val_mean_absolute_error: 0.1662
# Epoch 89/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1100 - mean_absolute_error: 0.2445 - val_loss: 0.0287 - val_mean_absolute_error: 0.1244
# Epoch 90/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1210 - mean_absolute_error: 0.2589 - val_loss: 0.0304 - val_mean_absolute_error: 0.1306
# Epoch 91/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1221 - mean_absolute_error: 0.2609 - val_loss: 0.0547 - val_mean_absolute_error: 0.1985
# Epoch 92/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1310 - mean_absolute_error: 0.2709 - val_loss: 0.0524 - val_mean_absolute_error: 0.1929
# Epoch 93/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1328 - mean_absolute_error: 0.2854 - val_loss: 0.0447 - val_mean_absolute_error: 0.1719
# Epoch 94/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1150 - mean_absolute_error: 0.2569 - val_loss: 0.0605 - val_mean_absolute_error: 0.2066
# Epoch 95/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1220 - mean_absolute_error: 0.2647 - val_loss: 0.0308 - val_mean_absolute_error: 0.1361
# Epoch 96/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1109 - mean_absolute_error: 0.2503 - val_loss: 0.0650 - val_mean_absolute_error: 0.2203
# Epoch 97/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1344 - mean_absolute_error: 0.2873 - val_loss: 0.0512 - val_mean_absolute_error: 0.1875
# Epoch 98/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1086 - mean_absolute_error: 0.2431 - val_loss: 0.0300 - val_mean_absolute_error: 0.1292
# Epoch 99/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1130 - mean_absolute_error: 0.2473 - val_loss: 0.0294 - val_mean_absolute_error: 0.1320
# Epoch 100/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1096 - mean_absolute_error: 0.2460 - val_loss: 0.0417 - val_mean_absolute_error: 0.1646

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 0s 4ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_prediction)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 plt.plot(dates_train, train_predictions)
#       2 plt.plot(dates_train, y_train)
# ----> 3 plt.plot(dates_val, val_prediction)
#       4 plt.plot(dates_val, y_val)
#       5 plt.plot(dates_test, test_predictions)
#
# NameError: name 'val_prediction' is not defined

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
